# %%
import pandas as pd
import json
import os
from PIL import Image

w4_labels = ['CAR', 'CAR_CIPV', 'VAN_NLV', 'TRUCK', 'VAN', 'CAR_NLV', 
             'BUS', 'TRUCK_NLV', 'BUS_CIPV', 'TRUCK_CIPV', 'BUS_NLV', 
             'VAN_CIPV', 'TRAILER', 'TOW_TRUCK', 'RV', 'CONSTRUCTION_VEHICLE', 'SPECIAL_4W', 'TRACTOR', 
             'PICK_UP_CAR', 'OPEN_CAR_DOOR', 'DUMMY_CAR', 'MISK', 'IGNORE_VEHICLE', 'MINI_TRUCK', 'OPEN_CAR_DOOR', 
             'CEMENT_MIXER_TRUCK']

ped_labels = ['PERSON', 'PERSON_MCP', 'CHILD', 'CHILD_MCP', 'IGNORE_PEDESTRIAN', 'DUMMY_PERSON', "PEDESTRIAN", 'PEDESTRIAN_MCP'] 

w2_labels = ['KICK_SCOOTER', 'BIKE', 'TRICYCLE', 'BIKE_NLV', 'MOTOR_NLV', 
             'BIKE_CIPV', 'MOTOR_CIPV', 'MOTOR_WITHOUT_RIDER', 'KICK_SCOOTER_CIPV', 'KICK_SCOOTER_NLV', 'MOTOR', 'IGNORE_BICYCLE']

rider_labels = ['RIDER_NLV', 'RIDER', 'RIDER_CIPV']

def get_label_id(label):
    if label in w4_labels:
        return 0
    elif label in w2_labels:
        return 1
    elif label in ped_labels:
        return 2
    elif label in rider_labels:
        return 3
    else:
        return -1  # Undefined category

def df_to_coco(df, images_path, output_file):
    coco_format = {
        "images": [],
        "annotations": [],
        "categories": [
            {"supercategory": None, "id": 0, "name": "2w"},
            {"supercategory": None, "id": 1, "name": "4w"},
            {"supercategory": None, "id": 2, "name": "ped"},
            {"supercategory": None, "id": 3, "name": "rider"}
        ]
    }

    image_set = {}
    annotation_id = 1

    # First, iterate through all unique images to assign IDs
    unique_images = df['name'].unique()
    for idx, image_name in enumerate(unique_images):
        image_path = os.path.join(images_path, image_name)
        if os.path.exists(image_path):
            with Image.open(image_path) as img:
                width, height = img.size

            image_info = {
                "file_name": os.path.join(images_path, image_name),
                "id": idx + 1,  # Start IDs from 1
                "width": width,
                "height": height
            }
            image_set[image_name] = image_info["id"]
            coco_format["images"].append(image_info)
        else:
            print(f"Image file {image_path} does not exist.")

    # Then, iterate through the rows to create annotations
    for _, row in df.iterrows():
        image_id = image_set.get(row["name"])
        if image_id is None:
            continue  # Skip if image_id is not found

        category_id = get_label_id(row["label"])
        if category_id == -1:
            continue  # Skip if category_id is undefined

        # Convert (x_center, y_center, width, height) to (top-left-x, top-left-y, width, height)
        x_center, y_center, width, height = row["x_center"], row["y_center"], row["width"], row["height"]
        top_left_x = x_center - (width / 2)
        top_left_y = y_center - (height / 2)

        annotation_info = {
            "id": annotation_id,
            "image_id": image_id,
            "category_id": category_id,
            "bbox": [top_left_x, top_left_y, width, height],
            "iscrowd": 0,
            "area": width * height,
            #"ignore": row["ignore_state"],
            #"attributes": {
            #    "is_occluded": row["is_occluded"],
            #    "is_truncated": row["is_truncated"],
            #    "d3_separation": row["d3_separation"] if pd.notna(row["d3_separation"]) else 0.0,
            #    "r_label": row["r_label"] if pd.notna(row["r_label"]) else "NaN",
            #    "is_rider_on_2_wheels": row["is_rider_on_2_wheels"],
            #    "occlusion_state_b2b": row["occlusion_state_b2b"],
            #    "is_on_road_bondery": row["is_on_road_bondery"],
            #    "l_label": row["l_label"] if pd.notna(row["l_label"]) else "NaN",
            #    "importance_state": row["importance_state"]
            #}
        }

        coco_format["annotations"].append(annotation_info)
        annotation_id += 1
    
    with open(output_file, 'w') as f:
        json.dump(coco_format, f, indent=4)

# %%
df = pd.read_csv("/home/b2b/arthur/data/921_hard_images/gt.tsv", sep = '\t')

# %%
df_to_coco(df, "/home/b2b/arthur/data/921_hard_images/images", "/home/b2b/arthur/data/921_hard_images/coco_labels.json")

# %%
import pandas as pd
import json
import os
from PIL import Image

# Label categories
w4_labels = ['CAR', 'CAR_CIPV', 'VAN_NLV', 'TRUCK', 'VAN', 'CAR_NLV', 
             'BUS', 'TRUCK_NLV', 'BUS_CIPV', 'TRUCK_CIPV', 'BUS_NLV', 
             'VAN_CIPV', 'TRAILER', 'TOW_TRUCK', 'RV', 'CONSTRUCTION_VEHICLE', 'SPECIAL_4W', 'TRACTOR', 
             'PICK_UP_CAR', 'OPEN_CAR_DOOR', 'DUMMY_CAR', 'MISK', 'MISC', 'IGNORE_VEHICLE', 'MINI_TRUCK', 'OPEN_CAR_DOOR', 
             'CEMENT_MIXER_TRUCK']

ped_labels = ['PERSON', 'PERSON_MCP', 'CHILD', 'CHILD_MCP', 'IGNORE_PEDESTRIAN', 'DUMMY_PERSON', "PEDESTRIAN", 'PEDESTRIAN_MCP'] 

w2_labels = ['KICK_SCOOTER', 'BIKE', 'TRICYCLE', 'BIKE_NLV', 'MOTOR_NLV', 
             'BIKE_CIPV', 'MOTOR_CIPV', 'MOTOR_WITHOUT_RIDER', 'KICK_SCOOTER_CIPV', 'KICK_SCOOTER_NLV', 'MOTOR', 'IGNORE_BICYCLE']

rider_labels = ['RIDER_NLV', 'RIDER', 'RIDER_CIPV']

ignore_labels = ["IGNORE_VEHICLE", "IGNORE_PEDESTRIAN", "IGNORE_BICYCLE", "IGNORE_RIDER"]

# Function to get label ID
def get_label_id(label):
    label = label.upper()
    if label in w4_labels:
        return 1
    elif label in w2_labels:
        return 0
    elif label in ped_labels:
        return 2
    elif label in rider_labels:
        return 3
    else:
        return -1  # Undefined category

# Function to convert DataFrame to COCO format JSON
def df_to_coco(df, images_path, coco_format, annotation_id, stats):
    image_set = {}
    
    # Iterate through all unique images to assign IDs
    unique_images = df['name'].unique()
    for idx, image_name in enumerate(unique_images):
        image_path = os.path.join(images_path, image_name)
        if os.path.exists(image_path):
            with Image.open(image_path) as img:
                width, height = img.size

            image_info = {
                "file_name": os.path.join(images_path, image_name),
                "id": len(coco_format["images"]) + 1,  # Start IDs from 1
                "width": width,
                "height": height
            }
            image_set[image_name] = image_info["id"]
            coco_format["images"].append(image_info)
        else:
            print(f"Image file {image_path} does not exist.")

    # Iterate through the rows to create annotations
    for _, row in df.iterrows():
        image_id = image_set.get(row["name"])
        if image_id is None:
            continue  # Skip if image_id is not found

        category_id = get_label_id(row["label"])
        if category_id == -1:
            continue  # Skip if category_id is undefined

        # Increment the corresponding category count
        stats[category_id] += 1

        # Convert (x_center, y_center, width, height) to (top-left-x, top-left-y, width, height)
        x_center, y_center, width, height = row["x_center"], row["y_center"], row["width"], row["height"]
        top_left_x = x_center - (width / 2)
        top_left_y = y_center - (height / 2)

        
        loss_weight = 3.0
        if row['label'].upper() in ignore_labels:
            loss_weight = 1.0


        annotation_info = {
            "id": annotation_id,
            "image_id": image_id,
            "category_id": category_id,
            "bbox": [top_left_x, top_left_y, width, height],
            "iscrowd": 0,
            "area": width * height,
            "loss_weight" : loss_weight
        }

        coco_format["annotations"].append(annotation_info)
        annotation_id += 1
    
    return coco_format, annotation_id, stats

# Main function to process all subdirectories
def process_all_folders(root_folder, output_file):
    coco_format = {
        "images": [],
        "annotations": [],
        "categories": [
            {"supercategory": None, "id": 0, "name": "2w"},
            {"supercategory": None, "id": 1, "name": "4w"},
            {"supercategory": None, "id": 2, "name": "ped"},
            {"supercategory": None, "id": 3, "name": "rider"}
        ]
    }
    annotation_id = 1
    stats = {0: 0, 1: 0, 2: 0, 3: 0}  # Initialize statistics counter

    # Iterate through all subdirectories in the root folder
    for subdir in os.listdir(root_folder):
        subdir_path = os.path.join(root_folder, subdir)
        if os.path.isdir(subdir_path):
            # Read the TSV file
            tsv_file = os.path.join(subdir_path, f"{subdir}_CorticaFormatGT.tsv")
            if os.path.exists(tsv_file):
                df = pd.read_csv(tsv_file, sep='\t')
                images_path = os.path.join(subdir_path, f"{subdir}_images")
                coco_format, annotation_id, stats = df_to_coco(df, images_path, coco_format, annotation_id, stats)
            else:
                print(f"TSV file {tsv_file} does not exist.")

    with open(output_file, 'w') as f:
        json.dump(coco_format, f, indent=4)

    # Print out the statistics
    print(f"Number of 2-wheelers (2w): {stats[0]}")
    print(f"Number of 4-wheelers (4w): {stats[1]}")
    print(f"Number of pedestrians (ped): {stats[2]}")
    print(f"Number of riders: {stats[3]}")

# Example usage
root_folder = "/mnt/data/OD_Data/8mp_data_kernel_1.7mp/"
output_file = "./all_data_coco_loss_weight_v2.json"
process_all_folders(root_folder, output_file)
# Out:
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/israel_urban_with_buses/israel_urban_with_buses_images/1690370164999596.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/israel_urban_with_buses/israel_urban_with_buses_images/1690370158033282.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/israel_urban_with_buses/israel_urban_with_buses_images/1690370166833088.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/israel_urban_with_buses/israel_urban_with_buses_images/1689859406133704.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/israel_urban_with_buses/israel_urban_with_buses_images/1689859415700384.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/israel_urban_with_buses/israel_urban_with_buses_images/1689859444066749.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/israel_urban_with_buses/israel_urban_with_buses_images/1689859418899945.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/israel_urban_with_buses/israel_urban_with_buses_images/1689859409800245.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/israel_urban_with_buses/israel_urban_with_buses_images/1689859444933377.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/israel_urban_with_buses/israel_urban_with_buses_images/1689859446333669.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/israel_urban_with_buses/israel_urban_with_buses_images/1689859429300123.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/israel_urban_with_buses/israel_urban_with_buses_images/1689859442400051.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/israel_urban_with_buses/israel_urban_with_buses_images/1689859416900176.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/israel_urban_with_buses/israel_urban_with_buses_images/1689859429333563.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/israel_urban_with_buses/israel_urban_with_buses_images/1689859401500131.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530803310684.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675531355516374.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/train_buses_images_8/train_buses_images_8_images/1667917437396440.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/train
png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/official_fakt_wolfsburg_paris_4w_classifier_2ws_02_03_23_for_train/official_fakt_wolfsburg_paris_4w_classifier_2ws_02_03_23_for_train_images/1667917559864779.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/official_fakt_wolfsburg_paris_4w_classifier_2ws_02_03_23_for_train/official_fakt_wolfsburg_paris_4w_classifier_2ws_02_03_23_for_train_images/1667917558031421.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/official_fakt_wolfsburg_paris_4w_classifier_2ws_02_03_23_for_train/official_fakt_wolfsburg_paris_4w_classifier_2ws_02_03_23_for_train_images/1667917554431371.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/official_fakt_wolfsburg_paris_4w_classifier_2ws_02_03_23_for_train/official_fakt_wolfsburg_paris_4w_classifier_2ws_02_03_23_for_train_images/1667917552698014.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/official_fakt_wolfsburg_paris_4w_classifier_2ws_02_03_23_for_train/official_fakt_wolfsburg_paris_4w_classifier_2ws_02_03_23_for_train_images/1667917551898003.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/official_fakt_wolfsburg_paris_4w_classifier_2ws_02_03_23_for_train/official_fakt_wolfsburg_paris_4w_classifier_2ws_02_03_23_for_train_images/1667917592198556.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/official_fakt_wolfsburg_paris_4w_classifier_2ws_02_03_23_for_train/official_fakt_wolfsburg_paris_4w_classifier_2ws_02_03_23_for_train_images/1667917685966515.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/official_fakt_wolfsburg_paris_4w_classifier_2ws_02_03_23_for_train/official_fakt_wolfsburg_paris_4w_classifier_2ws_02_03_23_for_train_images/1667917774934414.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/official_fakt_wolfsburg_paris_4w_classifier_2ws_02_03_23_for_train/official_fakt_wolfsburg_paris_4w_classifier_2ws_02_03_23_for_train_images/1667917771034360.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/europe_fog_train/europe_fog_train_images/1697621034666785.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/europe_fog_train/europe_fog_train_images/1697621020333251.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/europe_israel_usa_special_trucks_cement_mixer_and_buses_for_train/europe_israel_usa_special_trucks_cement_mixer_and_buses_for_train_images/1690372128100070.png does not exist.
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/europe_israel_usa_special_trucks_cement_mixer_and_buses_for_train/europe_israel_usa_special_trucks_cement_mixer_and_buses_for_train_images/1690898649999887.png does not exist.
# Number of 2-wheelers (2w): 102800
# Number of 4-wheelers (4w): 911490
# Number of pedestrians (ped): 216532
# Number of riders: 34655

# %%
df = pd.read_csv("/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_CorticaFormatGT.tsv", sep = '\t')

# %%
df.columns, df.name
# Out:
# (Index(['name', 'x_center', 'y_center', 'width', 'height', 'label',
#         'is_occluded', 'is_truncated', 'l_label', 'd3_separation', 'r_label',
#         'front_wheel', 'back_wheel', 'is_rider_on_2_wheels', 'is_not_in_lane'],
#        dtype='object'),
#  0        1675530774577055.png
#  1        1675530774577055.png
#  2        1675530774577055.png
#  3        1675530774577055.png
#  4        1675530774577055.png
#                   ...
#  13278    1675532134734928.png
#  13279    1675532134734928.png
#  13280    1675532134734928.png
#  13281    1675532134734928.png
#  13282    1675532134734928.png
#  Name: name, Length: 13283, dtype: object)

# %%
df_to_coco(df, "/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images",\
           coco_format, 0)
# Out:
# Image file /mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530803310684.png does not exist.
# ({'images': [{'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530774577055.png',
#     'id': 1,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530773710380.png',
#     'id': 2,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530772710369.png',
#     'id': 3,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530771877027.png',
#     'id': 4,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530771077019.png',
#     'id': 5,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530770043675.png',
#     'id': 6,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530769243667.png',
#     'id': 7,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530768476993.png',
#     'id': 8,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530767643651.png',
#     'id': 9,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530766910310.png',
#     'id': 10,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530766010300.png',
#     'id': 11,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530764776954.png',
#     'id': 12,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530804010691.png',
#     'id': 13,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530802910680.png',
#     'id': 14,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530801777335.png',
#     'id': 15,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530800777325.png',
#     'id': 16,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530800010650.png',
#     'id': 17,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530799010640.png',
#     'id': 18,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530798210631.png',
#     'id': 19,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530797377289.png',
#     'id': 20,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530796443947.png',
#     'id': 21,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530795543937.png',
#     'id': 22,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530794577261.png',
#     'id': 23,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530793743919.png',
#     'id': 24,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530792910577.png',
#     'id': 25,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530792110569.png',
#     'id': 26,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530791177226.png',
#     'id': 27,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530790243883.png',
#     'id': 28,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530789510542.png',
#     'id': 29,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530788743867.png',
#     'id': 30,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530787843858.png',
#     'id': 31,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530786943849.png',
#     'id': 32,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530786177175.png',
#     'id': 33,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530784910495.png',
#     'id': 34,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530813610790.png',
#     'id': 35,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530812210775.png',
#     'id': 36,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530810844095.png',
#     'id': 37,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530809444080.png',
#     'id': 38,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530808077400.png',
#     'id': 39,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675530806677385.png',
#     'id': 40,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675

#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532049200716.png',
#     'id': 848,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532047834035.png',
#     'id': 849,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532046434020.png',
#     'id': 850,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532045067340.png',
#     'id': 851,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532063600864.png',
#     'id': 852,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532062200849.png',
#     'id': 853,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532060834168.png',
#     'id': 854,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532059434154.png',
#     'id': 855,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532058067473.png',
#     'id': 856,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532056667459.png',
#     'id': 857,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532055300778.png',
#     'id': 858,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532074200973.png',
#     'id': 859,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532072834292.png',
#     'id': 860,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532071434277.png',
#     'id': 861,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532070067597.png',
#     'id': 862,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532068667582.png',
#     'id': 863,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532067300902.png',
#     'id': 864,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532065900887.png',
#     'id': 865,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532083901072.png',
#     'id': 866,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532082501058.png',
#     'id': 867,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532081134377.png',
#     'id': 868,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532079734363.png',
#     'id': 869,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532078367682.png',
#     'id': 870,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532076967667.png',
#     'id': 871,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532075600987.png',
#     'id': 872,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532094501181.png',
#     'id': 873,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532093101167.png',
#     'id': 874,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532091734486.png',
#     'id': 875,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532090334472.png',
#     'id': 876,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532088967791.png',
#     'id': 877,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532087567777.png',
#     'id': 878,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532086201096.png',
#     'id': 879,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532084801082.png',
#     'id': 880,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532103467940.png',
#     'id': 881,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532102067926.png',
#     'id': 882,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532100701245.png',
#     'id': 883,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532099301231.png',
#     'id': 884,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532097934550.png',
#     'id': 885,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532096534536.png',
#     'id': 886,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532095134521.png',
#     'id': 887,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532113834714.png',
#     'id': 888,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532112434699.png',
#     'id': 889,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532111068018.png',
#     'id': 890,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532109668004.png',
#     'id': 891,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532108267990.png',
#     'id': 892,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532106901309.png',
#     'id': 893,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532105501295.png',
#     'id': 894,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532124101486.png',
#     'id': 895,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532122701471.png',
#     'id': 896,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532121301457.png',
#     'id': 897,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532119934776.png',
#     'id': 898,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532118534762.png',
#     'id': 899,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532117168081.png',
#     'id': 900,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532115768067.png',
#     'id': 901,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532134368258.png',
#     'id': 902,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532132968243.png',
#     'id': 903,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532131568229.png',
#     'id': 904,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532130201549.png',
#     'id': 905,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532128801534.png',
#     'id': 906,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532127401520.png',
#     'id': 907,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532126034839.png',
#     'id': 908,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532137501624.png',
#     'id': 909,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532136101609.png',
#     'id': 910,
#     'width': 3840,
#     'height': 1920},
#    {'file_name': '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675532134734928.png',
#     'id': 911,
#     'width': 3840,
#     'height': 1920}],
#   'annotations': [],
#   'categories': [{'supercategory': None, 'id': 0, 'name': '2w'},
#    {'supercategory': None, 'id': 1, 'name': '4w'},
#    {'supercategory': None, 'id': 2, 'name': 'ped'},
#    {'supercategory': None, 'id': 3, 'name': 'rider'}]},
#  0)

# %%
coco_format = {
        "images": [],
        "annotations": [],
        "categories": [
            {"supercategory": None, "id": 0, "name": "2w"},
            {"supercategory": None, "id": 1, "name": "4w"},
            {"supercategory": None, "id": 2, "name": "ped"},
            {"supercategory": None, "id": 3, "name": "rider"}
        ]
    }

# %%
def get_all_labels(root_folder):
    all_labels = set()
    
    # Iterate through all subdirectories in the root folder
    for subdir in os.listdir(root_folder):
        subdir_path = os.path.join(root_folder, subdir)
        if os.path.isdir(subdir_path):
            # Read the TSV file
            tsv_file = os.path.join(subdir_path, f"{subdir}_CorticaFormatGT.tsv")
            if os.path.exists(tsv_file):
                df = pd.read_csv(tsv_file, sep='\t')
                unique_labels = df['label'].unique()
                all_labels.update(label.upper() for label in unique_labels)
            else:
                print(f"TSV file {tsv_file} does not exist.")
    
    return all_labels

# %%
#root_folder = '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/'
root_folder = '/mnt/data/OD_Data/od_full_training_set_for_data_effort'

labels = get_all_labels(root_folder)

# %%
for label in labels:
    if label not in w4_labels + w2_labels + ped_labels + rider_labels:
        if not "SIG" in label:
            print (label)
# Out:
# 2WHEELS_PR2
# TRAFFIC_LIGHT_4
# IGNORE_CONSTRUCTION_CONE
# CONSTRUCTION_CONE
# CAR_PR3
# TRAFFIC_LIGHT_3_V
# RIDER_AND_BIKE
# TRAFFIC_LIGHT_UNKNOWN_NUMBER
# ISLAND_TRAFFIC_LIGHT
# ARROW_RIGHT
# PERSON_PR2
# TIRE
# BACK_TRAFFIC_LIGHT
# PERSON_PR1
# REFLECTOR_POST
# TRAFFIC_LIGHT_4_V
# TRAFFIC_LIGHT
# TUNNEL
# 2WHEELS_PR1
# BLANK
# ARROW_LEFT
# SUN_RAY
# 2WHEELS_PR3
# CAR_PR1
# SUPPLEMENTARY_GENERAL
# TRAIN
# PERSON_PR3
# TRAFFIC_LIGHT_3
# TRAFFIC_LIGHT_2_V
# TRAFFIC_LIGHT_5
# CAR_PR2
# DISTANCE
# IGNORE_TRAFFIC_LIGHT
# TRAFFIC_LIGHT_2
# GENERAL_TRAFFIC_LIGHT
# TRAFFIC_LIGHT_1
# MISC

# %%
from glob import glob
from PIL import Image
from tqdm import tqdm

from glob import glob
from PIL import Image
from tqdm import tqdm
from multiprocessing import Pool, cpu_count

def check_image_integrity(image_path):
    try:
        with Image.open(image_path) as img:
            img.verify()  # Verify that the file is not broken or truncated
            return None  # Return None if the image is good
    except (IOError, SyntaxError) as e:
        return image_path  # Return the path if the image is bad

def process_images(images):
    with Pool(cpu_count()) as pool:
        bad_images = list(tqdm(pool.imap_unordered(check_image_integrity, images), total=len(images)))
        bad_images = [img for img in bad_images if img is not None]  # Filter out None values
    return bad_images
    
images = glob("/mnt/data/OD_Data/8mp_data_kernel_1.7mp/*/*/*.png")

bad_images = process_images(images)
# Out:
# 100%|██████████| 107043/107043 [10:53<00:00, 163.78it/s]

# %%
len(bad_images)
# Out:
# 1

# %%
bad_image = '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675531355516374.png'

good_image = images[100]

check_image_integrity(bad_image)
# Out:
# Truncated File Read
# '/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675531355516374.png'

# %%
check_image_integrity(good_image)

# %%
bad_images
# Out:
# ['/mnt/data/OD_Data/8mp_data_kernel_1.7mp/paris_night_urban_for_train_tagged_14_05_23/paris_night_urban_for_train_tagged_14_05_23_images/1675531355516374.png']

# %%
import os
os.system(f"mv {bad_image} ./")
# Out:
# 0
